# %% [markdown]
# #How To Train YOLOv5 Oriented Bounding Boxes Custom Object Detection
#
# Oriented bounding boxes are bounding boxes rotated to better fit the objects represented on an angle. In this notebook, we use the YOLOv5-OBB repository in order to train an already annotated dataset to view the Oriented bounding boxes detection at play.
#
#
# ## Instructions
#
# Run one cell at at time and run:
#
# ```
# >>> import torch
# >>> torch.version.cuda
# >>> exit()
# ```
#
# when prompted to in the first cell.
#
# Addidtional Resources:
#
# - [Yolov5-OBB installation instructions](https://github.com/hukaixuan19970627/yolov5_obb/blob/master/docs/install.md)
# - [Getting started](https://github.com/hukaixuan19970627/yolov5_obb/blob/master/docs/GetStart.md)

# %%
# !sudo apt-get update
# !sudo apt-get install libgl1 -y
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:2 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libgl1 is already the newest version (1.3.2-1~ubuntu0.20.04.2).
# 0 upgraded, 0 newly installed, 0 to remove and 181 not upgraded.

# %%
# !pip3 install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio==0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# !nvcc -V
# !nvidia-smi
# Out:
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# Requirement already satisfied: torch==1.10.1+cu113 in /home/u7701783/.local/lib/python3.8/site-packages (1.10.1+cu113)
# Requirement already satisfied: torchvision==0.11.2+cu113 in /home/u7701783/.local/lib/python3.8/site-packages (0.11.2+cu113)
# Requirement already satisfied: torchaudio==0.10.1+cu113 in /home/u7701783/.local/lib/python3.8/site-packages (0.10.1+cu113)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.8/site-packages (from torch==1.10.1+cu113) (3.10.0.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /home/u7701783/.local/lib/python3.8/site-packages (from torchvision==0.11.2+cu113) (9.3.0)
# Requirement already satisfied: numpy in /home/u7701783/.local/lib/python3.8/site-packages (from torchvision==0.11.2+cu113) (1.23.1)
# WARNING: You are using pip version 21.2.4; however, version 23.2 is available.
# You should consider upgrading via the '/opt/conda/bin/python3 -m pip install --upgrade pip' command.
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Wed_Jul_14_19:41:19_PDT_2021
# Cuda compilation tools, release 11.4, V11.4.100
# Build cuda_11.4.r11.4/compiler.30188945_0
# Mon Jul 17 20:45:36 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.161.03   Driver Version: 470.161.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:1C:00.0 Off |                    0 |
# | N/A   26C    P0    42W / 300W |      0MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#!git clone git@github.com:Suppersine/YOLOv7_obb_KFIOU.git
#!git clone https://github.com/SSTato/YOLOv7_obb.git

# %%
#%cd /content/yolov7_obb_expm/
# %cd ~/yolov7-obb/
# !pip install -r requirements.txt
# Out:
# /home/u7701783/yolov7-obb
# Requirement already satisfied: matplotlib>=3.2.2 in /home/u7701783/.local/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (3.4.3)
# Requirement already satisfied: numpy>=1.18.5 in /home/u7701783/.local/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (1.23.1)
# Requirement already satisfied: opencv-python>=4.5.4 in /home/u7701783/.local/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in /home/u7701783/.local/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (9.3.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/u7701783/.local/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (5.4.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (2.26.0)
# Requirement already satisfied: scipy>=1.4.1 in /home/u7701783/.local/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (1.9.1)
# Requirement already satisfied: torch>=1.7.0 in /home/u7701783/.local/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (1.10.1+cu113)
# Requirement already satisfied: torchvision>=0.8.1 in /home/u7701783/.local/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (0.11.2+cu113)
# Requirement already satisfied: tqdm>=4.41.0 in /home/u7701783/.local/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (4.62.2)
# Requirement already satisfied: tensorboard>=2.4.1 in /opt/conda/lib/python3.8/site-packages (from -r requirements.txt (line 16)) (2.6.0)
# Requirement already satisfied: pandas>=1.1.4 in /home/u7701783/.local/lib/python3.8/site-packages (from -r requirements.txt (line 20)) (1.3.5)
# Requirement already satisfied: seaborn>=0.11.0 in /home/u7701783/.local/lib/python3.8/site-packages (from -r requirements.txt (line 21)) (0.11.2)
# Requirement already satisfied: thop in /home/u7701783/.local/lib/python3.8/site-packages (from -r requirements.txt (line 37)) (0.0.31.post2005241907)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/u7701783/.local/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/u7701783/.local/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/u7701783/.local/lib/python3.8/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/u7701783/.local/lib/python3.8/site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.8/site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/u7701783/.local/lib/python3.8/site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/u7701783/.local/lib/python3.8/site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2021.5.30)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.8/site-packages (from torch>=1.7.0->-r requirements.txt (line 11)) (3.10.0.0)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (57.4.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.4.5)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/conda/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.6.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/conda/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.34.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (2.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/conda/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.8.0)
# Requirement already satisfied: protobuf>=3.6.0 in /opt/conda/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.17.3)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.13.0)
# Requirement already satisfied: grpcio>=1.24.3 in /opt/conda/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.39.0)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.36.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.8/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.3.4)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=1.1.4->-r requirements.txt (line 20)) (2021.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from absl-py>=0.4->tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.1.1)
# WARNING: You are using pip version 21.2.4; however, version 23.2 is available.
# You should consider upgrading via the '/opt/conda/bin/python3 -m pip install --upgrade pip' command.

# %%
# %cd utils/nms_rotated
# !python setup.py develop  #or "
# !pip install -v -e .
# Out:
# /home/u7701783/yolov7-obb/utils/nms_rotated
# running develop
# error: can't create or remove files in install directory
#
# The following error occurred while trying to add or remove files in the
# installation directory:
#
#     [Errno 13] Permission denied: '/opt/conda/lib/python3.8/site-packages/test-easy-install-1410.write-test'
#
# The installation directory you specified (via --install-dir, --prefix, or
# the distutils default setting) was:
#
#     /opt/conda/lib/python3.8/site-packages/
#
# Perhaps your account does not have write access to this directory?  If the
# installation directory is a system-owned directory, you may need to sign in
# as the administrator or "root" account.  If you do not have administrative
# access to this machine, you may wish to choose a different installation
# directory, preferably one that is listed in your PYTHONPATH environment
# variable.
#
# For information on other options, you may wish to consult the
# documentation at:
#
#   https://setuptools.readthedocs.io/en/latest/easy_install.html
#
# Please make the appropriate changes for your system and try again.
#
# Using pip 21.2.4 from /opt/conda/lib/python3.8/site-packages/pip (python 3.8)
# Obtaining file:///home/u7701783/yolov7-obb/utils/nms_rotated
#     Running command python setup.py egg_info
#     running egg_info
#     creating /tmp/pip-pip-egg-info-gl65o87w/nms_rotated.egg-info
#     writing /tmp/pip-pip-egg-info-gl65o87w/nms_rotated.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-gl65o87w/nms_rotated.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-gl65o87w/nms_rotated.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-gl65o87w/nms_rotated.egg-info/SOURCES.txt'
#     reading manifest file '/tmp/pip-pip-egg-info-gl65o87w/nms_rotated.egg-info/SOURCES.txt'
#     writing manifest file '/tmp/pip-pip-egg-info-gl65o87w/nms_rotated.egg-info/SOURCES.txt'
# Installing collected packages: nms-rotated
#   Attempting uninstall: nms-rotated
#     Found existing installation: nms-rotated 0.0.0
#     Uninstalling nms-rotated-0.0.0:
#       Removing file or directory /home/u7701783/.local/lib/python3.8/site-packages/nms-rotated.egg-link
#       Removing pth entries from /home/u7701783/.local/lib/python3.8/site-packages/easy-install.pth:
#       Removing entry: /home/u7701783/yolov7-obb/utils/nms_rotated
#       Successfully uninstalled nms-rotated-0.0.0
#   Running setup.py develop for nms-rotated
#     Running command /opt/conda/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/home/u7701783/yolov7-obb/utils/nms_rotated/setup.py'"'"'; __file__='"'"'/home/u7701783/yolov7-obb/utils/nms_rotated/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' develop --no-deps --user --prefix=
#     running develop
#     running egg_info
#     writing nms_rotated.egg-info/PKG-INFO
#     writing dependency_links to nms_rotated.egg-info/dependency_links.txt
#     writing top-level names to nms_rotated.egg-info/top_level.txt
#     reading manifest file 'nms_rotated.egg-info/SOURCES.txt'
#     writing manifest file 'nms_rotated.egg-info/SOURCES.txt'
#     running build_ext
#     building '.nms_rotated_ext' extension
#     Emitting ninja build file /home/u7701783/yolov7-obb/utils/nms_rotated/build/temp.linux-x86_64-3.8/build.ninja...
#     Compiling objects...
#     Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
#     /home/u7701783/.local/lib/python3.8/site-packages/torch/utils/cpp_extension.py:782: UserWarning: The detected CUDA version (11.4) has a minor version mismatch with the version that was used to compile PyTorch (11.3). Most likely this shouldn't be a problem.
#       warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
#     ninja: no work to do.
#     g++ -pthread -shared -B /opt/conda/compiler_compat -L/opt/conda/lib -Wl,-rpath=/opt/conda/lib -Wl,--no-as-needed -Wl,--sysroot=/ /home/u7701783/yolov7-obb/utils/nms_rotated/build/temp.linux-x86_64-3.8/src/nms_rotated_cpu.o /home/u7701783/yolov7-obb/utils/nms_rotated/build/temp.linux-x86_64-3.8/src/nms_rotated_ext.o /home/u7701783/yolov7-obb/utils/nms_rotated/build/temp.linux-x86_64-3.8/src/nms_rotated_cuda.o /home/u7701783/yolov7-obb/utils/nms_rotated/build/temp.linux-x86_64-3.8/src/poly_nms_cuda.o -L/home/u7701783/.local/lib/python3.8/site-packages/torch/lib -L/usr/local/cuda/lib64 -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda_cu -ltorch_cuda_cpp -o build/lib.linux-x86_64-3.8/nms_rotated_ext.cpython-38-x86_64-linux-gnu.so
#     copying build/lib.linux-x86_64-3.8/nms_rotated_ext.cpython-38-x86_64-linux-gnu.so ->
#     Creating /home/u7701783/.local/lib/python3.8/site-packages/nms-rotated.egg-link (link to .)
#     Adding nms-rotated 0.0.0 to easy-install.pth file
#
#     Installed /home/u7701783/yolov7-obb/utils/nms_rotated
# Successfully installed nms-rotated-0.0.0
# WARNING: You are using pip version 21.2.4; however, version 23.2 is available.
# You should consider upgrading via the '/opt/conda/bin/python3 -m pip install --upgrade pip' command.

# %%
#%cd /content
#!mkdir /content/datasets/

# %% [markdown]
# ##Export
#
# Remember to export your annotated dataset following the steps shown [in the video tutorial](https://youtu.be/iRkCNo9-slY?t=136)

# %%
#%cd /content/datasets/

#!pip install roboflow
"""
from roboflow import Roboflow
rf = Roboflow(api_key="fT5oyESQpvY2ntrSyCCW")
project = rf.workspace("gdit").project("aerial-airport")
dataset = project.version(1).download("yolov5-obb")"""
# Out:
# '\nfrom roboflow import Roboflow\nrf = Roboflow(api_key="fT5oyESQpvY2ntrSyCCW")\nproject = rf.workspace("gdit").project("aerial-airport")\ndataset = project.version(1).download("yolov5-obb")'

# %% [markdown]
# ## Rename dataset name to roboflow
#
# After running the `!pip install` package, our python.train will expect the dataset name to be `roboflow` (with or without changing the code path below). Make sure to change your cloned dataset folder name to `roboflow` before running the cell below.
#
# In other words, make sure your dataset structure is:
#
# ```
# parent
# ├── yolov5
# └── datasets
#     └── roboflow
#         ├── test
#         ├── train
#         └── valid
#             ├── images
#                  |────1.jpg
#                  |────...
#                  └────10000.jpg
#             ├── labelTxt
#                  |────1.txt
#                  |────...
#                  └────10000.txt
#         └────README.roboflow.txt
#         └────data.yaml
# ```

# %%
"""# Download trained weights
# %cd /content/yolov7_obb_expm/
# %cd /content/YOLOv7_obb_KFIOU/
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt"""
# Out:
# '# Download trained weights\n# %cd /content/yolov7_obb_expm/\n%cd /content/YOLOv7_obb_KFIOU/\n!wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt'

# %% [markdown]
# Before training the model, always rename the dataset to "roboflow", and point its address to:
#
# ```
# /content/datasets/roboflow/data.yaml
# ```

# %%
"""# os.rename
import os  
# %cd /content/datasets/
os.rename("/content/datasets/Aerial-Airport-1", "/content/datasets/roboflow")"""
# Out:
# '# os.rename\nimport os  \n%cd /content/datasets/\nos.rename("/content/datasets/Aerial-Airport-1", "/content/datasets/roboflow")'

# %%
# Commence Training the Model
# %cd /content/yolov7_obb_expm/
# %cd ~/yolov7-obb/
#!python trainnew.py --data ~/datasets/roboflow3/data2.yaml --hyp ~/yolov7-obb/dataset/hyp.med.yaml --weights yolov7.pt --mode 'CSL' --angmode 'LE90' --workers 4 --epochs 20 --batch-size 32 --imgsz 576 --device 0 --exist-ok  --name 'YOLOV7-test-csl-576a'
#!python trainnew.py --data ~/datasets/roboflow3/data2.yaml --hyp ~/yolov7-obb/dataset/hyp.med.yaml --weights yolov7.pt --mode 'CSL' --angmode 'LE90' --workers 8 --epochs 20 --batch-size 32 --imgsz 576 --device 0 --exist-ok  --name 'YOLOV7-test-csl-576b'
# !python trainnew.py --data ~/datasets/roboflow3/data2.yaml --hyp ~/yolov7-obb/dataset/hyp.med.yaml --weights yolov7.pt --mode 'CSL' --angmode 'LE90' --workers 4 --epochs 20 --batch-size 32 --imgsz 576 --device 0 --exist-ok  --name 'YOLOV7-test-csl-576a'
# !python trainnew.py --data ~/datasets/roboflow3/data2.yaml --hyp ~/yolov7-obb/dataset/hyp.med.yaml --weights yolov7.pt --mode 'CSL' --angmode 'LE90' --workers 8 --epochs 20 --batch-size 32 --imgsz 576 --device 0 --exist-ok  --name 'YOLOV7-test-csl-576b'
# !python trainnew.py --data ~/datasets/roboflow3/data2.yaml --hyp ~/yolov7-obb/dataset/hyp.med.yaml --weights yolov7.pt --mode 'CSL' --angmode 'LE90' --workers 4 --epochs 20 --batch-size 32 --imgsz 576 --device 0 --exist-ok  --name 'YOLOV7-test-csl-576a'
# Out:
# /home/u7701783/yolov7-obb
# LE90 angular definition mode selected
# wandb: Currently logged in as: supasin13rayong (use `wandb login --relogin` to force relogin)
# trainnew: weights=yolov7.pt, cfg=, data=/home/u7701783/datasets/roboflow3/data2.yaml, hyp=/home/u7701783/yolov7-obb/dataset/hyp.med.yaml, epochs=20, batch_size=32, imgsz=576, rect=False, resume=False, nosave=False, notest=False, noval=False, noautoanchor=False, evolve=False, bucket=, cache=None, cache_images=False, image_weights=False, device=0, multi_scale=False, single_cls=False, adam=False, optimizer=adam, sync_bn=False, local_rank=-1, workers=4, project=runs/train, name=YOLOV7-test-csl-576a, exist_ok=True, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, save_period=-1, freeze=[0], mode=CSL, angmode=LE90, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (Docker image), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 bf4fc14 torch 1.10.1+cu113 CUDA:0 (Tesla V100-SXM2-32GB, 32510MiB)
#
# CSL loss mode selected
# TRAIN notebook mode selected
# LE90 angular definition mode selected
# YOLOV7-test-csl-576a folder name selected
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.3, cls_pw=1.0, theta=0.5, theta_pw=1.0, obj=0.7, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=10.0, translate=0.2, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.0, mosaic=1.0, mixup=0.15, copy_paste=0.0, paste_in=0, cls_theta=180, csl_radius=2.0, loss_ota=0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# wandb: wandb version 0.15.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.9
# wandb: Syncing run YOLOV7-test-csl-576a
# wandb:  View project at https://wandb.ai/supasin13rayong/YOLOv5
# wandb:  View run at https://wandb.ai/supasin13rayong/YOLOv5/runs/3ggs2w0o
# wandb: Run data is saved locally in /home/u7701783/yolov7-obb/wandb/run-20230717_161753-3ggs2w0o
# wandb: Run `wandb offline` to turn off syncing.
#
# Overriding model.yaml nc=80 with nc=4
#
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   5                -2  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   6                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   7                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   8                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   9                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  10  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  11                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  12                -1  1         0  models.common.MP                        []
#  13                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  14                -3  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  16          [-1, -3]  1         0  models.common.Concat                    [1]
#  17                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  18                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  19                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  20                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  22                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  23  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  24                -1  1    263168  models.common.Conv                      [512, 512, 1, 1]
#  25                -1  1         0  models.common.MP                        []
#  26                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  27                -3  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  28                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  29          [-1, -3]  1         0  models.common.Concat                    [1]
#  30                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  31                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  32                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  33                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  34                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  35                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  36  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  37                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  38                -1  1         0  models.common.MP                        []
#  39                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  40                -3  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  41                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  42          [-1, -3]  1         0  models.common.Concat                    [1]
#  43                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  44                -2  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  45                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  46                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  47                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  48                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  49  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  50                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  51                -1  1   7609344  models.common.SPPCSPC                   [1024, 512, 1]
#  52                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  53                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  54                37  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  55          [-1, -2]  1         0  models.common.Concat                    [1]
#  56                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  57                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  58                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  59                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  60                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  61                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  62[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  63                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  64                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  65                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  66                24  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  67          [-1, -2]  1         0  models.common.Concat                    [1]
#  68                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  69                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  70                -1  1     73856  models.common.Conv                      [128, 64, 3, 1]
#  71                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  72                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  73                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  74[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  75                -1  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  76                -1  1         0  models.common.MP                        []
#  77                -1  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  78                -3  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  79                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  80      [-1, -3, 63]  1         0  models.common.Concat                    [1]
#  81                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  82                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  83                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  84                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  85                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  86                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  87[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  88                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  89                -1  1         0  models.common.MP                        []
#  90                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  91                -3  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  92                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  93      [-1, -3, 51]  1         0  models.common.Concat                    [1]
#  94                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  95                -2  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  96                -1  1   1180160  models.common.Conv                      [512, 256, 3, 1]
#  97                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  98                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  99                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
# 100[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
# 101                -1  1   1049600  models.common.Conv                      [2048, 512, 1, 1]
# 102                75  1    328704  models.common.RepConv                   [128, 256, 3, 1]
# 103                88  1   1312768  models.common.RepConv                   [256, 512, 3, 1]
# 104               101  1   5246976  models.common.RepConv                   [512, 1024, 3, 1]
# 105   [102, 103, 104]  1   1017765  models.yolo.Detect                      [4, [[12, 16, 19, 36, 40, 28], [36, 75, 76, 55, 72, 146], [142, 110, 192, 243, 459, 401]], [256, 512, 1024]]
# Model Summary: 407 layers, 38180165 parameters, 38180165 gradients, 107.9 GFLOPs
#
# Transferred 553/559 items from yolov7.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 92 weight, 95 weight (no decay), 95 bias
# train: Scanning '../datasets/roboflow3/train/labelTxt.cache' images and labels..
# train: WARNING: ../datasets/roboflow3/train/images/a2Npwq1lamdk-M32069_1.mp4-77.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/train/images/a2Npwq1lamdk-M32069_1.mp4-77.jpg'
# train: WARNING: ../datasets/roboflow3/train/images/amNnwq5lY8Kb-video3.mp4-45.jpg: ignoring corrupt image/label: 'LCA' is not in list
# train: WARNING: ../datasets/roboflow3/train/images/ampnwqZsacKW-video1.mp4-19.jpg: ignoring corrupt image/label: 'LCA' is not in list
# train: WARNING: ../datasets/roboflow3/train/images/amtiwq1pasKb-video1.mp4-28.jpg: ignoring corrupt image/label: 'LCA' is not in list
# train: WARNING: ../datasets/roboflow3/train/images/amtiwq1pasKb-video2.mp4-118.jpg: ignoring corrupt image/label: 'LCA' is not in list
# train: WARNING: ../datasets/roboflow3/train/images/amtiwq1pasKb-video3.mp4-165.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/train/images/amtiwq1pasKb-video3.mp4-165.jpg'
# train: WARNING: ../datasets/roboflow3/train/images/amtiwq1pasKb-video6.mp4-109.jpg: ignoring corrupt image/label: 'LCA' is not in list
# train: WARNING: ../datasets/roboflow3/train/images/amtiwq1pasKb-video8.mp4-59.jpg: ignoring corrupt image/label: 'RCA' is not in list
# val: Scanning '../datasets/roboflow3/valid/labelTxt.cache' images and labels...
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video18.mp4-77.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/valid/images/amtpwqhramk=-video18.mp4-77.jpg'
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video18.mp4-78.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/valid/images/amtpwqhramk=-video18.mp4-78.jpg'
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-150.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-150.jpg'
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-176.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-176.jpg'
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-177.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-177.jpg'
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-178.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-178.jpg'
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-179.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-179.jpg'
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-180.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-180.jpg'
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-181.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-181.jpg'
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-51.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-51.jpg'
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-52.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-52.jpg'
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-53.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-53.jpg'
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-54.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-54.jpg'
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-57.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-57.jpg'
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-58.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-58.jpg'
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-59.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3/valid/images/amtpwqhramk=-video19.mp4-59.jpg'
# val: WARNING: ../datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-8.jpg: ignoring corrupt image/label: 'RCA' is not in list
# Plotting labels to runs/train/YOLOV7-test-csl-576a/labels_xyls.jpg...
#
# AutoAnchor: 6.04 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# CSL loss mode selected
# CSL loss mode selected
# Image sizes 576 train, 576 val
# Using 4 dataloader workers
# Logging results to runs/train/YOLOV7-test-csl-576a
# Starting training for 20 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     theta    labels  img_size
#       0/19     21.3G    0.1141   0.01587   0.02724    0.3984        14       576
#                Class     Images     Labels          P          R  HBBmAP@.5  HBB
#                  all        187          0          0          0          0          0
# YOLOV7-test-csl-576a folder name selected
#
#      Epoch   gpu_mem       box       obj       cls     theta    labels  img_size
#       1/19     25.2G   0.09752    0.0174   0.02542    0.3263        17       576
#                Class     Images     Labels          P          R  HBBmAP@.5  HBB
#                  all        187          0          0          0          0          0
# YOLOV7-test-csl-576a folder name selected
#
#      Epoch   gpu_mem       box       obj       cls     theta    labels  img_size
#       2/19     25.2G   0.08847   0.01783   0.02424    0.2841        19       576
#                Class     Images     Labels          P          R  HBBmAP@.5  HBB
#                  all        187          0          0          0          0          0
# YOLOV7-test-csl-576a folder name selected
#
#      Epoch   gpu_mem       box       obj       cls     theta    labels  img_size
#       3/19     25.2G   0.08933   0.01647    0.0231    0.2486        26       576
#                Class     Images     Labels          P          R  HBBmAP@.5  HBB
#                  all        187        245    0.00431     0.0177    0.00234   0.000394
# YOLOV7-test-csl-576a folder name selected
#
#      Epoch   gpu_mem       box       obj       cls     theta    labels  img_size
#       4/19     25.2G   0.09331   0.01498   0.02236    0.2217        23       576
#                Class     Images     Labels          P          R  HBBmAP@.5  HBB
#                  all        187        245     0.0261     0.0276     0.0088    0.00147
# YOLOV7-test-csl-576a folder name selected
#
#      Epoch   gpu_mem       box       obj       cls     theta    labels  img_size
#
�▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁
# wandb:           val/box_loss ▇▅▅██▆▇▇▅▅▆▇▅▂▄▂▁▃▁▄
# wandb:           val/cls_loss █▅▃▃▃▂▅▄▃▁▅▂▃▁▂▂▁▁▃▃
# wandb:           val/obj_loss ▇█▇▄▃▃▃▂▂▂▂▁▂▃▂▃▃▂▃▂
# wandb:         val/theta_loss █▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                  x/lr0 ▁▂▃▄▅▆▇▇██████▇▇▆▅▅▄
# wandb:                  x/lr1 ▁▂▃▄▅▆▇▇██████▇▇▆▅▅▄
# wandb:                  x/lr2 ██▇▇▇▆▆▆▅▅▄▄▄▃▃▃▂▂▁▁
# wandb:
# wandb: Run summary:
# wandb:       metrics/HBBmAP.5 0.31131
# wandb:   metrics/HBBmAP.5:.95 0.08031
# wandb:      metrics/precision 0.2417
# wandb:         metrics/recall 0.61859
# wandb:         train/box_loss 0.0748
# wandb:         train/cls_loss 0.01067
# wandb:         train/obj_loss 0.00868
# wandb:       train/theta_loss 0.16542
# wandb:           val/box_loss 0.07726
# wandb:           val/cls_loss 0.01772
# wandb:           val/obj_loss 0.00925
# wandb:         val/theta_loss 0.19432
# wandb:                  x/lr0 0.00075
# wandb:                  x/lr1 0.00075
# wandb:                  x/lr2 0.04885
# wandb:
# wandb: Synced 5 W&B file(s), 342 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Synced YOLOV7-test-csl-576a: https://wandb.ai/supasin13rayong/YOLOv5/runs/3ggs2w0o
# wandb: Find logs at: ./wandb/run-20230717_161753-3ggs2w0o/logs/debug.log
# wandb:
# Results saved to runs/train/YOLOV7-test-csl-576a
# LE90 angular definition mode selected
# wandb: Currently logged in as: supasin13rayong (use `wandb login --relogin` to force relogin)
# trainnew: weights=yolov7.pt, cfg=, data=/home/u7701783/datasets/roboflow3/data2.yaml, hyp=/home/u7701783/yolov7-obb/dataset/hyp.med.yaml, epochs=20, batch_size=32, imgsz=576, rect=False, resume=False, nosave=False, notest=False, noval=False, noautoanchor=False, evolve=False, bucket=, cache=None, cache_images=False, image_weights=False, device=0, multi_scale=False, single_cls=False, adam=False, optimizer=adam, sync_bn=False, local_rank=-1, workers=8, project=runs/train, name=YOLOV7-test-csl-576b, exist_ok=True, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, save_period=-1, freeze=[0], mode=CSL, angmode=LE90, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (Docker image), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 bf4fc14 torch 1.10.1+cu113 CUDA:0 (Tesla V100-SXM2-32GB, 32510MiB)
#
# CSL loss mode selected
# TRAIN notebook mode selected
# LE90 angular definition mode selected
# YOLOV7-test-csl-576b folder name selected
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.3, cls_pw=1.0, theta=0.5, theta_pw=1.0, obj=0.7, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=10.0, translate=0.2, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.0, mosaic=1.0, mixup=0.15, copy_paste=0.0, paste_in=0, cls_theta=180, csl_radius=2.0, loss_ota=0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# wandb: wandb version 0.15.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.9
# wandb: Syncing run YOLOV7-test-csl-576b
# wandb:  View project at https://wandb.ai/supasin13rayong/YOLOv5
# wandb:  View run at https://wandb.ai/supasin13rayong/YOLOv5/runs/1rfvannp
# wandb: Run data is saved locally in /home/u7701783/yolov7-obb/wandb/run-20230717_162316-1rfvannp
# wandb: Run `wandb offline` to turn off syncing.
#
# Overriding model.yaml nc=80 with nc=4
#
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   5                -2  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   6                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   7                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   8                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   9                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  10  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  11                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  12                -1  1         0  models.common.MP                        []
#  13                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  14                -3  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  16          [-1, -3]  1         0  models.common.Concat                    [1]
#  17                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  18                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  19                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  20                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  22                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  23  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  24                -1  1    263168  models.common.Conv                      [512, 512, 1, 1]
#  25                -1  1         0  models.common.MP                        []
#  26                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  27                -3  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  28                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  29          [-1, -3]  1         0  models.common.Concat                    [1]
#  30                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  31                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  32                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  33                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  34                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  35                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  36  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  37                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  38                -1  1         0  models.common.MP                        []
#  39                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  40                -3  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  41                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  42          [-1, -3]  1         0  models.common.Concat                    [1]
#  43                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  44                -2  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  45                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  46                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  47                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  48                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  49  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  50                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  51                -1  1   7609344  models.common.SPPCSPC                   [1024, 512, 1]
#  52                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  53                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  54                37  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  55          [-1, -2]  1         0  models.common.Concat                    [1]
#  56                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  57                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  58                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  59                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  60                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  61                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  62[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  63                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  64                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  65                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  66                24  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  67          [-1, -2]  1         0  models.common.Concat                    [1]
#  68                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  69                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  70                -1  1     73856  models.common.Conv                      [128, 64, 3, 1]
#  71                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  72                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  73                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  74[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  75                -1  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  76                -1  1         0  models.common.MP                        []
#  77                -1  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  78                -3  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  79                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  80      [-1, -3, 63]  1         0  models.common.Concat                    [1]
#  81                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  82                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  83                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  84                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  85                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  86                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  87[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  88                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  89                -1  1         0  models.common.MP                        []
#  90                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  91                -3  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  92                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  93      [-1, -3, 51]  1         0  models.common.Concat                    [1]
#  94                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  95                -2  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  96                -1  1   1180160  models.common.Conv                      [512, 256, 3, 1]
#  97                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  98                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  99                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
# 100[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
# 101                -1  1   1049600  models.common.Conv                      [2048, 512, 1, 1]
# 102                75  1    328704  models.common.RepConv                   [128, 256, 3, 1]
# 103                88  1   1312768  models.common.RepConv                   [256, 512, 3, 1]
# 104               101  1   5246976  models.common.RepConv                   [512, 1024, 3, 1]
# 105   [102, 103, 104]  1   1017765  models.yolo.Detect                      [4, [[12, 16, 19, 36, 40, 28], [36, 75, 76, 55, 72, 146], [142, 110, 192, 243, 459, 401]], [256, 512, 1024]]
# Model Summary: 407 layers, 38180165 parameters, 38180165 gradients, 107.9 GFLOPs
#
# Transferred 553/559 items from yolov7.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 92 weight, 95 weight (no decay), 95 bias
# train: Scanning '../datasets/roboflow3/train/labelTxt.cache' images and labels..
# train: WARNING: ../datasets/roboflow3/train/images/a2Npwq1lamdk-M32069_1.mp4-77.jpg: ignoring corrupt image/label: cannot identify image file '../datasets/roboflow3
# YOLOV7-test-csl-576b folder name selected
#
#      Epoch   gpu_mem       box       obj       cls     theta    labels  img_size
#      18/19     25.2G   0.06637  0.008756   0.01052    0.1656        21       576
#                Class     Images     Labels          P          R  HBBmAP@.5  HBB
#                  all        187        245       0.18      0.447      0.207     0.0619
# YOLOV7-test-csl-576b folder name selected
#
#      Epoch   gpu_mem       box       obj       cls     theta    labels  img_size
#      19/19     25.2G   0.07503   0.00835   0.01033    0.1643        27       576
#                Class     Images     Labels          P          R  HBBmAP@.5  HBB
#                  all        187        245      0.245      0.536      0.272     0.0938
# YOLOV7-test-csl-576b folder name selected
#
# 20 epochs completed in 0.074 hours.
# Optimizer stripped from runs/train/YOLOV7-test-csl-576b/weights/last.pt, 76.8MB
# Optimizer stripped from runs/train/YOLOV7-test-csl-576b/weights/best.pt, 76.8MB
#
# Validating runs/train/YOLOV7-test-csl-576b/weights/best.pt...
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 37465381 parameters, 6194944 gradients, 106.5 GFLOPs
#                Class     Images     Labels          P          R  HBBmAP@.5  HBB
#                  all        187        245      0.311      0.556        0.3     0.0864
# YOLOV7-test-csl-576b folder name selected
#       LCA-brightness        187         29     0.0502      0.552     0.0492     0.0125
#       LCA-dilatation        187        198      0.309      0.475      0.261     0.0608
#       RCA-brightness        187          7      0.254      0.571      0.304      0.053
#       RCA-dilatation        187         11      0.632      0.624      0.585      0.219
#
# wandb: Waiting for W&B process to finish, PID 4757... (success).
# wandb:
# wandb: Run history:
# wandb:       metrics/HBBmAP.5 ▁▁▁▁▁▂▂▁▄▃▃▄▅▆▆▇▅█▅▇
# wandb:   metrics/HBBmAP.5:.95 ▁▁▁▁▁▁▂▁▄▄▃▅▆▄▅▇▅█▅▇
# wandb:      metrics/precision ▁▁▁▁▁██▄▃█▃▄▄▄▄▄▃▅▃▄
# wandb:         metrics/recall ▁▁▁▃▃▁▂▃▆▃▂▃▆▆▆▆██▆▇
# wandb:         train/box_loss █▅▄▄▅▅▅▅▅▅▅▄▄▃▃▃▂▂▁▂
# wandb:         train/cls_loss █▇▇▆▆▅▅▄▃▃▃▂▂▂▁▁▁▁▁▁
# wandb:         train/obj_loss ▇▇██▆▅▄▃▃▂▂▂▂▂▂▁▂▂▁▁
# wandb:       train/theta_loss █▆▅▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁
# wandb:           val/box_loss ▇▄▄▆▆▅▄█▃▆▅▅▃▄▃▃▁▁▂▂
# wandb:           val/cls_loss █▆▄▄▃▃▄▃▃▆▃▄▅▄▄▄▁▃▂▁
# wandb:           val/obj_loss ▇█▇▅▄▄▃▁▃▁▂▁▂▁▁▂▁▂▁▂
# wandb:         val/theta_loss █▅▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                  x/lr0 ▁▂▃▄▅▆▇▇██████▇▇▆▅▅▄
# wandb:                  x/lr1 ▁▂▃▄▅▆▇▇██████▇▇▆▅▅▄
# wandb:                  x/lr2 ██▇▇▇▆▆▆▅▅▄▄▄▃▃▃▂▂▁▁
# wandb:
# wandb: Run summary:
# wandb:       metrics/HBBmAP.5 0.27157
# wandb:   metrics/HBBmAP.5:.95 0.09379
# wandb:      metrics/precision 0.24455
# wandb:         metrics/recall 0.53563
# wandb:         train/box_loss 0.07503
# wandb:         train/cls_loss 0.01033
# wandb:         train/obj_loss 0.00835
# wandb:       train/theta_loss 0.16427
# wandb:           val/box_loss 0.06815
# wandb:           val/cls_loss 0.01463
# wandb:           val/obj_loss 0.00982
# wandb:         val/theta_loss 0.19331
# wandb:                  x/lr0 0.00075
# wandb:                  x/lr1 0.00075
# wandb:                  x/lr2 0.04885
# wandb:
# wandb: Synced 5 W&B file(s), 342 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Synced YOLOV7-test-csl-576b: https://wandb.ai/supasin13rayong/YOLOv5/runs/1rfvannp
# wandb: Find logs at: ./wandb/run-20230717_162316-1rfvannp/logs/debug.log
# wandb:
# Results saved to runs/train/YOLOV7-test-csl-576b

# %%
# %cd ~/yolov7-obb/
# !python detectsieved.py --weights 'runs/train/yv7kld576/weights/best.pt' --source ~/datasets/roboflow3/valid/images --conf-thres 0.01 --img 495 700 --device 0 --agnostic --mode 'KLD' --angmode 'LE90' --name 'yv7kld576_test'
# Out:
# /home/u7701783/yolov7-obb
# LE90 angular definition mode selected
# detectsieved: weights=['runs/train/yv7kld576/weights/best.pt'], source=/home/u7701783/datasets/roboflow3/valid/images, imgsz=[495, 700], conf_thres=0.01, iou_thres=0.4, max_det=100, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=True, augment=False, visualize=False, update=False, project=runs/detect, name=yv7kld576_test, exist_ok=False, line_thickness=2, hide_labels=False, hide_conf=True, half=False, dnn=False, detectmode=DETECT, mode=KLD, angmode=LE90
# KLD loss mode selected
# DETECT notebook mode selected
# LE90 angular definition mode selected
# YOLOv5 🚀 bf4fc14 torch 1.10.1+cu113 CUDA:0 (Tesla V100-SXM2-32GB, 32510MiB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 37465381 parameters, 6194944 gradients, 106.5 GFLOPs
# WARNING: --img-size [495, 700] must be multiple of max stride 32, updating to [512, 704]
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 1/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-109.jpg: 512x704 4 LCA-brightnesss, 6 LCA-dilatations, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 1/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-109.jpg: 512x704 4 LCA-brightnesss, 6 LCA-dilatations, 1 RCA-dilatation, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 2/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-11.jpg: 512x704 2 LCA-brightnesss, 9 LCA-dilatations, 5 RCA-brightnesss, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 2/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-11.jpg: 512x704 2 LCA-brightnesss, 9 LCA-dilatations, 5 RCA-brightnesss, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-brightness, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 3/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-12.jpg: 512x704 11 LCA-dilatations, 1 RCA-brightness, 2 RCA-dilatations, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 3/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-12.jpg: 512x704 11 LCA-dilatations, 1 RCA-brightness, 2 RCA-dilatations, 512x704 1 LCA-dilatation, 1 RCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 4/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-13.jpg: 512x704 2 LCA-brightnesss, 9 LCA-dilatations, 2 RCA-dilatations, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 4/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-13.jpg: 512x704 2 LCA-brightnesss, 9 LCA-dilatations, 2 RCA-dilatations, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 5/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-14.jpg: 512x704 3 LCA-brightnesss, 7 LCA-dilatations, 1 RCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 5/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-14.jpg: 512x704 3 LCA-brightnesss, 7 LCA-dilatations, 1 RCA-brightness, 1 RCA-dilatation, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 6/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-15.jpg: 512x704 4 LCA-brightnesss, 3 LCA-dilatations, 2 RCA-brightnesss, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 6/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-15.jpg: 512x704 4 LCA-brightnesss, 3 LCA-dilatations, 2 RCA-brightnesss, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-brightness, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 7/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-16.jpg: 512x704 4 LCA-brightnesss, 6 LCA-dilatations, 3 RCA-brightnesss, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 7/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-16.jpg: 512x704 4 LCA-brightnesss, 6 LCA-dilatations, 3 RCA-brightnesss, 1 RCA-dilatation, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([2, 10])
# image 8/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-17.jpg: 512x704 3 LCA-dilatations, 1 RCA-brightness, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([2, 10])
# image 8/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-17.jpg: 512x704 3 LCA-dilatations, 1 RCA-brightness, 512x704 1 LCA-dilatation, 1 RCA-brightness, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 9/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-33.jpg: 512x704 1 LCA-brightness, 6 LCA-dilatations, 3 RCA-brightnesss, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 9/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-33.jpg: 512x704 1 LCA-brightness, 6 LCA-dilatations, 3 RCA-brightnesss, 1 RCA-dilatation, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 10/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-55.jpg: 512x704 5 LCA-brightnesss, 7 LCA-dilatations, 1 RCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 10/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-55.jpg: 512x704 5 LCA-brightnesss, 7 LCA-dilatations, 1 RCA-brightness, 1 RCA-dilatation, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 11/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-86.jpg: 512x704 8 LCA-dilatations, 3 RCA-brightnesss, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 11/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-86.jpg: 512x704 8 LCA-dilatations, 3 RCA-brightnesss, 1 RCA-dilatation, 512x704 1 LCA-dilatation, 1 RCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 12/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-87.jpg: 512x704 2 LCA-brightnesss, 11 LCA-dilatations, 1 RCA-brightness, 3 RCA-dilatations, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 12/204 /home/u7701783/datasets/roboflow3/valid/images/Z2NiwqllasKUwp0=-video1.mp4-87.jpg: 512x704 2 LCA-brightnesss, 11 LCA-dilatations, 1 RCA-brightness, 3 RCA-dilatations, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image
jpg: 512x704 1 LCA-brightness, 1 LCA-dilatation, 3 RCA-brightnesss, 3 RCA-dilatations, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 189/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-56.jpg: 512x704 1 LCA-brightness, 1 LCA-dilatation, 3 RCA-brightnesss, 3 RCA-dilatations, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 190/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-6.jpg: 512x704 1 LCA-brightness, 2 LCA-dilatations, 5 RCA-brightnesss, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 190/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-6.jpg: 512x704 1 LCA-brightness, 2 LCA-dilatations, 5 RCA-brightnesss, 1 RCA-dilatation, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 191/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-7.jpg: 512x704 2 LCA-brightnesss, 2 LCA-dilatations, 7 RCA-brightnesss, 3 RCA-dilatations, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 191/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-7.jpg: 512x704 2 LCA-brightnesss, 2 LCA-dilatations, 7 RCA-brightnesss, 3 RCA-dilatations, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 192/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-8.jpg: 512x704 3 LCA-brightnesss, 2 LCA-dilatations, 6 RCA-brightnesss, 2 RCA-dilatations, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 192/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-8.jpg: 512x704 3 LCA-brightnesss, 2 LCA-dilatations, 6 RCA-brightnesss, 2 RCA-dilatations, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 193/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-82.jpg: 512x704 4 LCA-brightnesss, 3 LCA-dilatations, 4 RCA-dilatations, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 193/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-82.jpg: 512x704 4 LCA-brightnesss, 3 LCA-dilatations, 4 RCA-dilatations, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 194/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-83.jpg: 512x704 7 LCA-brightnesss, 3 LCA-dilatations, 1 RCA-brightness, 3 RCA-dilatations, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 194/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-83.jpg: 512x704 7 LCA-brightnesss, 3 LCA-dilatations, 1 RCA-brightness, 3 RCA-dilatations, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 195/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-84.jpg: 512x704 4 LCA-brightnesss, 2 LCA-dilatations, 2 RCA-dilatations, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 195/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-84.jpg: 512x704 4 LCA-brightnesss, 2 LCA-dilatations, 2 RCA-dilatations, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([2, 10])
# image 196/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-85.jpg: 512x704 2 LCA-brightnesss, 2 RCA-dilatations, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([2, 10])
# image 196/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-85.jpg: 512x704 2 LCA-brightnesss, 2 RCA-dilatations, 512x704 1 LCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 197/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-86.jpg: 512x704 3 LCA-brightnesss, 1 LCA-dilatation, 1 RCA-brightness, 3 RCA-dilatations, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 197/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-86.jpg: 512x704 3 LCA-brightnesss, 1 LCA-dilatation, 1 RCA-brightness, 3 RCA-dilatations, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 198/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-9.jpg: 512x704 1 LCA-brightness, 2 LCA-dilatations, 7 RCA-brightnesss, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([4, 10])
# image 198/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video4.mp4-9.jpg: 512x704 1 LCA-brightness, 2 LCA-dilatations, 7 RCA-brightnesss, 1 RCA-dilatation, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-brightness, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([1, 10])
# image 199/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video5.mp4-19.jpg: 512x704 6 LCA-brightnesss, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([1, 10])
# image 199/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video5.mp4-19.jpg: 512x704 6 LCA-brightnesss, 512x704 1 LCA-brightness, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 200/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video5.mp4-30.jpg: 512x704 4 LCA-brightnesss, 4 LCA-dilatations, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([3, 10])
# image 200/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video5.mp4-30.jpg: 512x704 4 LCA-brightnesss, 4 LCA-dilatations, 1 RCA-dilatation, 512x704 1 LCA-brightness, 1 LCA-dilatation, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([2, 10])
# image 201/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video5.mp4-35.jpg: 512x704 7 LCA-dilatations, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([2, 10])
# image 201/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video5.mp4-35.jpg: 512x704 7 LCA-dilatations, 1 RCA-dilatation, 512x704 1 LCA-dilatation, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([2, 10])
# image 202/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video6.mp4-28.jpg: 512x704 2 LCA-brightnesss, 9 LCA-dilatations, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([2, 10])
# image 202/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video6.mp4-28.jpg: 512x704 2 LCA-brightnesss, 9 LCA-dilatations, 512x704 1 LCA-brightness, 1 LCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([2, 10])
# image 203/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video7.mp4-19.jpg: 512x704 3 LCA-dilatations, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([2, 10])
# image 203/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video7.mp4-19.jpg: 512x704 3 LCA-dilatations, 1 RCA-dilatation, 512x704 1 LCA-dilatation, 1 RCA-dilatation, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([2, 10])
# image 204/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video8.mp4-27.jpg: 512x704 12 LCA-dilatations, 3 RCA-dilatations, Done. (0.014s)
# after sieving, the det2.size is:
# torch.Size([2, 10])
# image 204/204 /home/u7701783/datasets/roboflow3/valid/images/amtpwqhramk=-video8.mp4-27.jpg: 512x704 12 LCA-dilatations, 3 RCA-dilatations, 512x704 1 LCA-dilatation, 1 RCA-dilatation, Done. (0.014s)
# Speed: 0.2ms pre-process, 6.8ms inference, 0.8ms NMS per image at shape (1, 3, 512, 704)
# Results saved to runs/detect/yv7kld576_test6

# %%
# %cd /content/yolov5_obb/runs/detect/exp/

# %%
import os, random
random_file = random.choice(os.listdir("/content/yolov5_obb/runs/detect/exp"))

from IPython.display import Image
Image(random_file)
